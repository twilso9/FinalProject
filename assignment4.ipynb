# %%
#allow output from every line
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pandas as pd
import numpy as np

# %%
#NFC South 2023 team rosters
#...("file",index_col='') set index

atl_roster_2023 = pd.read_csv("ATL Roster 2023.csv",index_col='Player')
atl_roster_2023
car_roster_2023 = pd.read_csv("CAR Roster 2023.csv",index_col='Player')
no_roster_2023 = pd.read_csv("NO Roster 2023.csv",index_col='Player')
tb_roster_2023 = pd.read_csv("TB Roster 2023.csv",index_col='Player')
# Out:
#                           No.  Age Pos   G  GS   Wt    Ht  \
# Player
# Logan Woodside           11.0   28  QB   1   0  201   6-2
# Desmond Ridder            9.0   24  QB  15  13  207   6-3
# Taylor Heinicke           4.0   30  QB   5   4  210   6-1
# Avery Williams (IR)      26.0   25  RB   0   0  195   5-9
# Carlos Washington (NWT)  28.0   25  RB   0   0  220  5-11
# ...                       ...  ...  ..  ..  ..  ...   ...
# Richie Grant             27.0   26   S  17  15  200   6-0
# Jessie Bates III          3.0   26   S  17  17  200   6-1
# Micah Abernathy          29.0   26   S  12   0  196   6-0
# Younghoe Koo              6.0   29   K  17   0  185   5-9
# Bradley Pinion           13.0   29   P  17   0  229   6-5
#
#                                    College/Univ   BirthDate   Yrs    AV  \
# Player
# Logan Woodside                           Toledo   1/27/1995     3   0.0
# Desmond Ridder                       Cincinnati   8/31/1999     1   9.0
# ...

# %%
#pd.concat([team1,team2,team3])
nfc_south = pd.concat([atl_roster_2023,car_roster_2023,no_roster_2023,tb_roster_2023])
nfc_south

#write csv
nfc_south.to_csv("NFC_South_Rosters_2023.csv")
# Out:
#                           No.  Age Pos   G  GS   Wt    Ht  \
# Player
# Logan Woodside           11.0   28  QB   1   0  201   6-2
# Desmond Ridder            9.0   24  QB  15  13  207   6-3
# Taylor Heinicke           4.0   30  QB   5   4  210   6-1
# Avery Williams (IR)      26.0   25  RB   0   0  195   5-9
# Carlos Washington (NWT)  28.0   25  RB   0   0  220  5-11
# ...                       ...  ...  ..  ..  ..  ...   ...
# Christian Izien          29.0   23   S  17   4  197   5-8
# Josh Hayes               32.0   24  DB  15   0  197  5-11
# Dee Delaney              30.0   28  DB  17   2  200  5-11
# Chase McLaughlin          4.0   27   K  17   0  175   6-1
# Jake Camarda              5.0   24   P  17   0  193   6-1
#
#                                                College/Univ   BirthDate   Yrs  \
# Player
# Logan Woodside                                       Toledo   1/27/1995     3
# Desmond Ridder                                   Cincinnati   8/31/1999     1
# ...
